# %% [markdown]
# ## Markdown cell Title
#
# With **some** text

# %% [markdown]
# And an ordered list with formatting:
#
# 1. Here is *one*
# 1. Here is __two__
# 1. Here is _three_ [with a link](https://github.com/ideonate/nb2xls)

# %%
import numpy as np
import pandas as pd
dates = pd.date_range('20130101',periods=6)
pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
# Out:
#                    A         B         C         D
# 2013-01-01  0.061798 -1.003758 -0.429696 -0.133860
# 2013-01-02  0.878302 -0.514656 -2.382516  0.985938
# 2013-01-03  0.143303 -0.807777  0.578240  0.731304
# 2013-01-04  0.112671  0.576712  0.992654  0.500250
# 2013-01-05  1.148595 -0.706012  1.537294  0.879467
# 2013-01-06  0.062397 -0.772768  0.225553 -1.435154

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, axs = plt.subplots(2, 2)
for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')
for ax in axs.flat:
    ax.label_outer()
